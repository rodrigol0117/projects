# %% [markdown]
# # Question 3
# a. Create a python function to calculate the first principal component of of the following dataset.
#
# b. Plot the projection of each point in the dataset with the first principal component from part a. Are you able to classify which moon each sample came from using just the first component?
#
# c. Write a python function that implements the Kernel PCA method, using a radial basis function kernel, $k(x,y) = e^{-γ||x-y||}$.
#
# Remember to center the kernel matrix using the formula $\hat{K} = K - \mathbb{I}_N K - K \mathbb{I}_N + \mathbb{I}_N K \mathbb{I}_N  $, where $\mathbb{I}_N$ is a square matrix of ones, the same size as K.
#
# d. Plot the projection of each point in the dataset with the first principal component from part c. Are you able to classify which moon each sample came from using just the first component? What is the first principal component?

# %%
import matplotlib.pyplot as plt

from sklearn.datasets import make_moons
X, y = make_moons(n_samples=200, random_state=123)

plt.figure(figsize=(8,6))

plt.scatter(X[y==0, 0], X[y==0, 1], color='red', alpha=0.5)
plt.scatter(X[y==1, 0], X[y==1, 1], color='blue', alpha=0.5)

plt.show()
